# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import lxml
import json
import time
import csv
import random

# %%
# Библиотеки для веб-драйвера Selenium

from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

service = Service(executable_path=ChromeDriverManager().install())

# %%
# Объединяем файлы ссылок в единый датафрейм

lnk_csv = 'https://raw.githubusercontent.com/ArtemDorofeev/Kinopoisk/main/csv/df_{}.csv'
df_full = pd.DataFrame()

for i in range(2015, 2023):
    data = pd.read_csv(lnk_csv.format(i))
    data['year'] = i
    df_full = pd.concat([df_full, data], ignore_index=True)

# %%
df_full = df_full[['name', 'links', 'year']]
df_full
# Out:
#                                 name                                    links  \
# 0                     Игра престолов  https://www.kinopoisk.ru/series/464963/
# 1                        Рик и Морти  https://www.kinopoisk.ru/series/685246/
# 2                            Легенда    https://www.kinopoisk.ru/film/839954/
# 3                          Марсианин    https://www.kinopoisk.ru/film/841700/
# 4                        Головоломка    https://www.kinopoisk.ru/film/645118/
# ...                              ...                                      ...
# 377994            Музыка летней ночи   https://www.kinopoisk.ru/film/5073920/
# 377995                      Пингвины   https://www.kinopoisk.ru/film/5074010/
# 377996                      Прогресс   https://www.kinopoisk.ru/film/5074011/
# 377997                        Прятки   https://www.kinopoisk.ru/film/5074012/
# 377998  Фантасмагория в стиле модерн   https://www.kinopoisk.ru/film/5074019/
#
#         year
# 0       2015
# 1       2015
# 2       2015
# 3       2015
# 4       2015
# ...      ...
# 377994  2022
# 377995  2022
# 377996  2022
# 377997  2022
# 377998  2022
#
# [377999 rows x 3 columns]

# %%
# Удаляем дубликаты ссылок

duplicate = df_full['links'].duplicated()
duplicate.value_counts()

df = df_full.drop(index=df_full[duplicate].index, axis=0)
df

# %%
# Категоризируем на фильмы и сериалы

def split_serials(row):
    if 'film' in row:
        x = 'film'
    else:
        x = 'series'
    return x

# %%
df['type'] = df['links'].apply(split_serials)
df
# Out:
#                                 name                                    links  \
# 0                     Игра престолов  https://www.kinopoisk.ru/series/464963/
# 1                        Рик и Морти  https://www.kinopoisk.ru/series/685246/
# 2                            Легенда    https://www.kinopoisk.ru/film/839954/
# 3                          Марсианин    https://www.kinopoisk.ru/film/841700/
# 4                        Головоломка    https://www.kinopoisk.ru/film/645118/
# ...                              ...                                      ...
# 377994            Музыка летней ночи   https://www.kinopoisk.ru/film/5073920/
# 377995                      Пингвины   https://www.kinopoisk.ru/film/5074010/
# 377996                      Прогресс   https://www.kinopoisk.ru/film/5074011/
# 377997                        Прятки   https://www.kinopoisk.ru/film/5074012/
# 377998  Фантасмагория в стиле модерн   https://www.kinopoisk.ru/film/5074019/
#
#         year    type
# 0       2015  series
# 1       2015  series
# 2       2015    film
# 3       2015    film
# 4       2015    film
# ...      ...     ...
# 377994  2022    film
# 377995  2022    film
# 377996  2022    film
# 377997  2022    film
# 377998  2022    film
#
# [348024 rows x 4 columns]

# %%
# Раззбиваем датасет по годам

df_2015 = df[df['year'] == 2015]
df_2016 = df[df['year'] == 2016]
df_2017 = df[df['year'] == 2017]
df_2018 = df[df['year'] == 2018]
df_2019 = df[df['year'] == 2019]
df_2020 = df[df['year'] == 2020]
df_2021 = df[df['year'] == 2021]
df_2022 = df[df['year'] == 2022]

# %%
df_2016
# Out:
#                                            name  \
# 36950                                Зверополис
# 36952                                     Мажор
# 36953                            Доктор Стрэндж
# 36954                                    Дэдпул
# 36955                                    Шерлок
# ...                                         ...
# 79495                                    Eiland
# 79496     K.E.R.O.S.E.N.E poems from the planet
# 79497                                    Cooker
# 79498  Devils & Angels, Ritual Feasts in Europe
# 79499                   Последний ужин на двоих
#
#                                          links  year    type
# 36950    https://www.kinopoisk.ru/film/775276/  2016    film
# 36952  https://www.kinopoisk.ru/series/820638/  2016  series
# 36953    https://www.kinopoisk.ru/film/409600/  2016    film
# 36954    https://www.kinopoisk.ru/film/462360/  2016    film
# 36955  https://www.kinopoisk.ru/series/502838/  2016  series
# ...                                        ...   ...     ...
# 79495    https://www.kinopoisk.ru/film/996604/  2016    film
# 79496    https://www.kinopoisk.ru/film/996606/  2016    film
# 79497    https://www.kinopoisk.ru/film/996607/  2016    film
# 79498    https://www.kinopoisk.ru/film/996608/  2016    film
# 79499   https://www.kinopoisk.ru/film/1047049/  2016    film
#
# [39252 rows x 4 columns]

# %%
# Формируем суп-объект

def get_soup(url):    
    driver.get(url)    
    html = driver.page_source
    soup = BeautifulSoup(html, "lxml")
    #info_section = soup.select('div.styles_root__2kxYy')
    return soup

# %%
# Собираем характеристики фильмов

def get_top(row):
    list_top = []
    try:
        name = row.select_one('h1[class*="styles_title"]').get_text()
    except:
        name = []
    
    try:
        description = row.select_one('div[class*="styles_topText"]').get_text()
    except:
        description = []
        
    try:
        rating = row.select_one('span[class*="film-rating-value"]').get_text()
    except:
        rating = []
        
    try:
        grades = row.select_one('div[class*="styles_countBlock"]').get_text()
    except:
        grades = []
    
    dic = {'name': name, 'description': description, 'rating': rating, 'grades': grades}
    list_top.append(dic)
    return list_top

def get_about(row):    
    about_block = row.select_one('div[data-test-id*="encyclopedic-table"]')
    about_row = about_block.select('div[class*="styles_row"]')
    list_about = []
    for i in about_block:
        try:            
            title = i.select_one('div[class*="styles_title"]').get_text()
            values = i.select('div[class*="styles_value"]')    
            dic = {title: values}
        except:
            dic = {}
        list_about.append(dic)        
    return list_about


def get_actor(row):
    list_actor = []
    try:        
        actor_block = row.select('div[class*="styles_actors"] ul li')        
        for i in actor_block:
            link = i.select_one('a').get('href')
            actor_name = i.get_text()
            dic = {'actor_name': actor_name, 'link': link}
            list_actor.append(dic)
    except:
        list_actor = list_actor
    return list_actor

def get_low(row):    
    try:
        critic_section = row.select_one('div[class*="styles_criticRatingSection"]')    
        try:
            critic_positive = critic_section.select_one('span[class*="film-rating-value"]').get_text()
        except:
            critic_positive = []
        try:   
            critic_value = critic_section.select_one('div[class*="styles_countBlock"]').get_text()
        except:
            critic_value = []
        try:
            critic_star = critic_section.select_one('div[class*="styles_starValue"]').get_text()
        except:
            critic_star = []
        lst = [critic_positive, critic_value, critic_star]
    except:
        lst = []
    return lst

# %%
# Формируем единый словарь характеристик

def full_parse(row):    
    #time.sleep(tm)
    soup = get_soup(row)
    name_rate = get_top(soup)
    about_film = get_about(soup)
    actors = get_actor(soup)
    critic_rate = get_low(soup)
    dic = {'name_rate': name_rate, 'about_film': about_film, 'actors': actors, 'critic_rate': critic_rate}
    return dic

# %%
driver = webdriver.Chrome(service=service) # Открывает новую отдельную вкладку браузера хром от selenium

# %%
# ЗАПУСК ПАРСЕРА!!!

df_2016['char'] = df_2016['links'].apply(full_parse)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 # ЗАПУСК ПАРСЕРА!!!
# ----> 3 df_2016['char'] = df_2016['links'].apply(full_parse)
#
# File C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File C:\Users\Admin\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [26], in full_parse(row)
#       3 def full_parse(row):
#       4     #time.sleep(tm)
# ----> 5     soup = get_soup(row)
#       6     name_rate = get_top(soup)
#       7     about_film = get_about(soup)
#
# Input In [24], in get_soup(url)
#       4 driver.get(url)
#       5 html = driver.page_source
# ----> 6 soup = BeautifulSoup(html, "lxml")
#       7 #info_section = soup.select('div.styles_root__2kxYy')
#       8 return soup
#
# File C:\Users\Admin\anaconda3\lib\site-packages\bs4\__init__.py:333, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331 self.builder.initialize_soup(self)
#     332 try:
# --> 333     self._feed()
#     334     success = True
#     335     break
#
# File C:\Users\Admin\anaconda3\lib\site-packages\bs4\__init__.py:451, in BeautifulSoup._feed(self)
#     448 # Convert the document to Unicode.
#     449 self.builder.reset()
# --> 451 self.builder.feed(self.markup)
#     452 # Close out any unfinished strings and close all the open tags.
#     453 self.endData()
#
# File C:\Users\Admin\anaconda3\lib\site-packages\bs4\builder\_lxml.py:378, in LXMLTreeBuilder.feed(self, markup)
#     376 try:
#     377     self.parser = self.parser_for(encoding)
# --> 378     self.parser.feed(markup)
#     379     self.parser.close()
#     380 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# File src/lxml/parser.pxi:1256, in lxml.etree._FeedParser.feed()
#
# File src/lxml/parser.pxi:1376, in lxml.etree._FeedParser.feed()
#
# File src/lxml/parsertarget.pxi:168, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/etree.pyx:333, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src/lxml/saxparser.pxi:443, in lxml.etree._handleSaxTargetStartNoNs()
#
# File src/lxml/saxparser.pxi:458, in lxml.etree._callTargetSaxStart()
#
# File src/lxml/parsertarget.pxi:94, in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# File C:\Users\Admin\anaconda3\lib\site-packages\bs4\builder\_lxml.py:301, in LXMLTreeBuilderForXML.start(self, name, attrs, nsmap)
#     299 namespace, name = self._getNsTag(name)
#     300 nsprefix = self._prefix_for_namespace(namespace)
# --> 301 self.soup.handle_starttag(
#     302     name, namespace, nsprefix, attrs,
#     303     namespaces=self.active_namespace_prefixes[-1]
#     304 )
#
# File C:\Users\Admin\anaconda3\lib\site-packages\bs4\__init__.py:721, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     716 if (self.parse_only and len(self.tagStack) <= 1
#     717     and (self.parse_only.text
#     718          or not self.parse_only.search_tag(name, attrs))):
#     719     return None
# --> 721 tag = self.element_classes.get(Tag, Tag)(
#     722     self, self.builder, name, namespace, nsprefix, attrs,
#     723     self.currentTag, self._most_recent_element,
#     724     sourceline=sourceline, sourcepos=sourcepos,
#     725     namespaces=namespaces
#     726 )
#     727 if tag is None:
#     728     return tag
#
# File C:\Users\Admin\anaconda3\lib\site-packages\bs4\element.py:1243, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1241 elif attrs:
#    1242     if builder is not None and builder.cdata_list_attributes:
# -> 1243         attrs = builder._replace_cdata_list_attribute_values(
#    1244             self.name, attrs)
#    1245     else:
#    1246         attrs = dict(attrs)
#
# File C:\Users\Admin\anaconda3\lib\site-packages\bs4\builder\__init__.py:319, in TreeBuilder._replace_cdata_list_attribute_values(self, tag_name, attrs)
#     314 for attr in list(attrs.keys()):
#     315     if attr in universal or (tag_specific and attr in tag_specific):
#     316         # We have a "class"-type attribute whose string
#     317         # value is a whitespace-separated list of
#     318         # values. Split it into a list.
# --> 319         value = attrs[attr]
#     320         if isinstance(value, str):
#     321             values = nonwhitespace_re.findall(value)
#
# KeyboardInterrupt:

# %%
df_2016
# Out:
#                                            name  \
# 36950                                Зверополис
# 36952                                     Мажор
# 36953                            Доктор Стрэндж
# 36954                                    Дэдпул
# 36955                                    Шерлок
# ...                                         ...
# 79495                                    Eiland
# 79496     K.E.R.O.S.E.N.E poems from the planet
# 79497                                    Cooker
# 79498  Devils & Angels, Ritual Feasts in Europe
# 79499                   Последний ужин на двоих
#
#                                          links  year    type
# 36950    https://www.kinopoisk.ru/film/775276/  2016    film
# 36952  https://www.kinopoisk.ru/series/820638/  2016  series
# 36953    https://www.kinopoisk.ru/film/409600/  2016    film
# 36954    https://www.kinopoisk.ru/film/462360/  2016    film
# 36955  https://www.kinopoisk.ru/series/502838/  2016  series
# ...                                        ...   ...     ...
# 79495    https://www.kinopoisk.ru/film/996604/  2016    film
# 79496    https://www.kinopoisk.ru/film/996606/  2016    film
# 79497    https://www.kinopoisk.ru/film/996607/  2016    film
# 79498    https://www.kinopoisk.ru/film/996608/  2016    film
# 79499   https://www.kinopoisk.ru/film/1047049/  2016    film
#
# [39252 rows x 4 columns]

# %%
#df_2015['char'][46179]

# %%
df_2016.to_csv('D:\\Data\\Kinopoisk\\csv\\df_full_2016.csv') # здесь надо указать свой путь на компе для записи файла

# %%
driver.quit()
