# %%
# Подключаем библиотеки

import pandas as pd
import numpy as np
import json
import csv
import os

# %%
# Получаем список дирректорий с CSV файлами

dirs = os.listdir(path="D:\\Data\\Kinopoisk\\CSV\\characteristics")

# %%
# Объединяем все CSV файлы из нескольких дирректорий

lnk = 'D:\\Data\\Kinopoisk\\CSV\\characteristics\\{}'
dataset = pd.DataFrame()
for i in dirs:
    lst = lnk.format(i)
    fls = os.listdir(path=lst)
    for j in fls:
        d = pd.read_csv(lst+'\\'+j)
        dataset = pd.concat([dataset, d], ignore_index=True)

# %%
# Обзор итогового датасета

dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 # Обзор итогового датасета
# ----> 3 dataset
#
# NameError: name 'dataset' is not defined

# %%
# Создаем копию датасета

df = dataset.copy()
df.sample(10)
# Out:
#         Unnamed: 0                      name  \
# 117601      167601  The Witches of the Watch
# 238946      288946      Framed by the Killer
# 142111      192111     Pikahsso - Troubadour
# 54211       104211        Death at Christmas
# 170757      220757             Jack and Jill
# 212181      262181               Seema Sagar
# 236298      286298        Monstrous Disunion
# 23438        29438        And Baby Makes One
# 176785      226785                 The Dummy
# 280345      332345                 GoldBlood
#
#                                            links  year    type  \
# 117601    https://www.kinopoisk.ru/film/1170413/  2018    film
# 238946  https://www.kinopoisk.ru/series/4291842/  2021  series
# 142111    https://www.kinopoisk.ru/film/1319600/  2019    film
# 54211     https://www.kinopoisk.ru/film/1097738/  2017    film
# 170757    https://www.kinopoisk.ru/film/1399123/  2019    film
# 212181    https://www.kinopoisk.ru/film/1420637/  2020    film
# 236298    https://www.kinopoisk.ru/film/1356431/  2021    film
# 23438      https://www.kinopoisk.ru/film/966469/  2015    film
# 176785    https://www.kinopoisk.ru/film/1132257/  2019    film
# 280345    https://www.kinopoisk.ru/film/4750673/  2022    film
#
#                                                      char
# 117601  [[{'name': 'The Witches of the Watch (2018)', ...
# 238946  [[{'name': 'Framed by the Killer (сериал 2021)...
# 142111  [[{'name': 'Pikahsso - Troubadour (2019)', 'de...
# 54211   [[{'name': 'Death at Christmas (2017)', 'descr...
# 170757  [[{'name': 'Jack and Jill (2019)', 'descriptio...
# 212181  [[{'name': 'Seema Sagar (2020)', 'description'...
# 236298  [[{'name': 'Monstrous Disunion (2021)', 'descr...
# 23438   [[{'name': 'And Baby Makes One (2015)', 'descr...
# 176785  [[{'name': 'The Dummy (2019)', 'description': ...
# 280345  [[{'name': 'GoldBlood (2022)', 'description': ...

# %%
# Убираем строки с пустыми списками характеристик (выдавали ошибку 404)

df = df[df['char'] != '[]']

# %%
# Преобразуем стрковый формат характеристик в список

df['charlist'] = df['char'].apply(lambda x: eval(x))

# %%
# Сохраняем целевые поля в датасете

df = df[['name', 'links', 'year', 'type', 'charlist']]
df.sample(8)
# Out:
#                          name                                     links  year  \
# 74345            Точка отрыва    https://www.kinopoisk.ru/film/1035521/  2018
# 188515   A Ring for Christmas    https://www.kinopoisk.ru/film/1238268/  2020
# 37779      No Love Like Yours     https://www.kinopoisk.ru/film/992640/  2016
# 318757          Night Terrors     https://www.kinopoisk.ru/film/925514/  2016
# 101408            G.I. JoBurg  https://www.kinopoisk.ru/series/5219997/  2018
# 246569                   Cata    https://www.kinopoisk.ru/film/4385044/  2021
# 313933                   Véra    https://www.kinopoisk.ru/film/1100858/  2016
# 131314  Затерянная гробница 2  https://www.kinopoisk.ru/series/1273747/  2019
#
#           type                                           charlist
# 74345     film  [[{'name': 'Точка отрыва (2018)', 'description...
# 188515    film  [[{'name': 'A Ring for Christmas (ТВ, 2020)', ...
# 37779     film  [[{'name': 'No Love Like Yours (2016)', 'descr...
# 318757    film  [[{'name': 'Night Terrors (2016)', 'descriptio...
# 101408  series  [[{'name': 'G.I. JoBurg (сериал 2018)', 'descr...
# 246569    film  [[{'name': 'Cata (2021)', 'description': 'none...
# 313933    film  [[{'name': 'Véra (2016)', 'description': 'none...
# 131314  series  [[{'name': 'Затерянная гробница 2 (сериал 2019...

# %%
df.to_csv('D:\\Data\\Kinopoisk\\CSV\\Total_datasets\\chars_total.csv')

# %%
# Разбиваем словарь с названием, годом выпуска и описанием фильма по столбцам

df['full_name'] = df['charlist'].apply(lambda x: x[0][0]['name'])
df['rating'] = df['charlist'].apply(lambda x: x[0][0]['rating'])
df['quant_grad'] = df['charlist'].apply(lambda x: x[0][0]['grades'])
df['description'] = df['charlist'].apply(lambda x: x[0][0])

# %%
# Определяем функцию для составления списка всех уникальных заголовков характеристик

merg = []

def keys_unique(row):
    dcts = row[1]
    for i in dcts:
        k = list(i)
        if k not in merg:
            merg.append(k)

# %%
# Применяем функцию к серии со списком характеристик

df['charlist'].apply(keys_unique)
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 355995    None
# 355996    None
# 355997    None
# 355998    None
# 355999    None
# Name: charlist, Length: 355307, dtype: object

# %%
# Список заголовков всех характеристик фильма

merg
# Out:
# [['Год производства'],
#  ['Платформа'],
#  ['Страна'],
#  ['Жанр'],
#  ['Слоган'],
#  ['Режиссер'],
#  ['Сценарий'],
#  ['Продюсер'],
#  ['Оператор'],
#  ['Композитор'],
#  ['Художник'],
#  ['Монтаж'],
#  ['Премьера в Росcии'],
#  ['Премьера в мире'],
#  ['Цифровой релиз'],
#  ['Релиз на DVD'],
#  ['Релиз на Blu-ray'],
#  ['Возраст'],
#  ['Время'],
#  ['Бюджет'],
#  ['Сборы в США'],
#  ['Сборы в мире'],
#  ['Сборы в России'],
#  ['Рейтинг MPAA'],
#  ['Зрители'],
#  ['Ре-релиз (РФ)'],
#  ['Директор фильма'],
#  ['Маркетинг']]

# %%
# Определяем функцию распределения значений характеристик по отдельным столбцам

def podbor(row):
    global i
    x = row[1]
    for j in x:
        if i == list(j):
            n = j.get(i[0])
            break
        else:
            n = 'none'
    return n

# %%
# Выделяем каждую характеристику из общего списка в отдельный столбец

for i in merg:
    df[i[0]] = df['charlist'].apply(podbor)

# %%
df.sample(8)
# Out:
#                                  name  \
# 170071                Africa Overland
# 118002                 Mr. Greenfield
# 35685                      WWE Барьер
# 154167                     101 Knocks
# 196745                      Scapegoat
# 287843                     The Radish
# 280943  Trick or Treat, Alistair Gray
# 222994                    Ausgebremst
#
#                                            links  year    type  \
# 170071    https://www.kinopoisk.ru/film/1384456/  2019    film
# 118002    https://www.kinopoisk.ru/film/1205816/  2018    film
# 35685      https://www.kinopoisk.ru/film/966064/  2016    film
# 154167    https://www.kinopoisk.ru/film/1274492/  2019    film
# 196745    https://www.kinopoisk.ru/film/4779293/  2020    film
# 287843    https://www.kinopoisk.ru/film/5068464/  2022    film
# 280943    https://www.kinopoisk.ru/film/5027044/  2022    film
# 222994  https://www.kinopoisk.ru/series/4368950/  2020  series
#
#                                                  charlist  \
# 170071  [[{'name': 'Africa Overland (2019)', 'descript...
# 118002  [[{'name': 'Mr. Greenfield (2018)', 'descripti...
# 35685   [[{'name': 'WWE Барьер (ТВ, 2016)', 'descripti...
# 154167  [[{'name': '101 Knocks (2019)', 'description':...
# 196745  [[{'name': 'Scapegoat (2020)', 'description': ...
# 287843  [[{'name': 'The Radish (2022)', 'description':...
# 280943  [[{'name': 'Trick or Treat, Alistair Gray (202...
# 222994  [[{'name': 'Ausgebremst (мини–сериал 2020)', '...
#
#                                    full_name rating quant_grad  \
# 170071                Africa Overland (2019)      –
# 118002                 Mr. Greenfield (2018)      –
# 35685                  WWE Барьер (ТВ, 2016)      –
# 154167                     101 Knocks (2019)      –
# 196745                      Scapegoat (2020)      –
# 287843                     The Radish (2022)      –
# 280943  Trick or Treat, Alistair Gray (2022)      –
# 222994        Ausgebremst (мини–сериал 2020)      –
#
#                                               description  Год производства  \
# 170071  {'name': 'Africa Overland (2019)', 'descriptio...            [2019]
# 118002  {'name': 'Mr. Greenfield (2018)', 'description...            [2018]
# 35685   {'name': 'WWE Барьер (ТВ, 2016)', 'description...            [2016]
# 154167  {'name': '101 Knocks (2019)', 'description': '...            [2019]
# 196745  {'name': 'Scapegoat (2020)', 'description': 'n...            [2020]
# 287843  {'name': 'The Radish (2022)', 'description': '...            [2022]
# 280943  {'name': 'Trick or Treat, Alistair Gray (2022)...            [2022]
# 222994  {'name': 'Ausgebremst (мини–сериал 2020)', 'de...  [2020, 2 сезона]
#
#         ...            Время Бюджет Сборы в США Сборы в мире Сборы в России  \
# 170071  ...  80 мин. / 01:20   none        none         none           none
# 118002  ...          30 мин.   none        none         none           none
# 35685   ...                —   none        none         none           none
# 154167  ...          12 мин.   none        none         none           none
# 196745  ...                —   none        none         none           none
# 287843  ...                —   none        none         none           none
# 280943  ...                —   none        none         none           none
# 222994  ...                —   none        none         none           none
#
#        Рейтинг MPAA Зрители Ре-релиз (РФ) Директор фильма Маркетинг
# 170071         none    none          none            none      none
# 118002         none    none          none            none      none
# 35685          none    none          none            none      none
# 154167         none    none          none            none      none
# 196745         none    none          none            none      none
# 287843         none    none          none            none      none
# 280943         none    none          none            none      none
# 222994         none    none          none            none      none
#
# [8 rows x 37 columns]

# %%
# Определяем функцию по выделению значения характеристики из списка

def sort(row):
    if type(row) == list:
        lst = []
        for i in row:
            val = i[0]
            if val != '...':
                lst.append(val)
        return lst
    else:
        return row

# %%
# Отделяем значения характеристик от второстепенных данных списка

for i in merg:
    df[i[0]] = df[i[0]].apply(sort)

# %%
df[df['links'] == 'https://www.kinopoisk.ru/film/843649/']
# Out:
#                                 name                                  links  \
# 73470  Мстители: Война бесконечности  https://www.kinopoisk.ru/film/843649/
#
#        year  type                                           charlist  \
# 73470  2018  film  [[{'name': 'Мстители: Война бесконечности (201...
#
#                                   full_name rating      quant_grad  \
# 73470  Мстители: Война бесконечности (2018)    8.1  761 727 оценок
#
#                                              description Год производства  \
# 73470  {'name': 'Мстители: Война бесконечности (2018)...           [2018]
#
#        ...             Время          Бюджет     Сборы в США  \
# 73470  ...  149 мин. / 02:29  [$321 000 000]  [$678 815 482]
#
#                                      Сборы в мире Сборы в России  \
# 73470  [+ $1 369 544 272 = $2 048 359 754, сборы]  [$34 793 936]
#
#                                      Рейтинг MPAA Зрители Ре-релиз (РФ)  \
# 73470  PG-13детям до 13 лет просмотр не желателен    none          none
#
#       Директор фильма Маркетинг
# 73470            none      none
#
# [1 rows x 37 columns]

# %%
df.loc[73470]
# Out:
# name                                     Мстители: Война бесконечности
# links                            https://www.kinopoisk.ru/film/843649/
# year                                                              2018
# type                                                              film
# charlist             [[{'name': 'Мстители: Война бесконечности (201...
# full_name                         Мстители: Война бесконечности (2018)
# rating                                                             8.1
# quant_grad                                              761 727 оценок
# description          {'name': 'Мстители: Война бесконечности (2018)...
# Год производства                                                [2018]
# Платформа                                                         none
# Страна                                                           [США]
# Жанр                          [фантастика, боевик, приключения, слова]
# Слоган                          «An entire universe. Once and for all»
# Режиссер                                     [Энтони Руссо, Джо Руссо]
# Сценарий                   [Кристофер Маркус, Стивен МакФили, Стэн Ли]
# Продюсер                    [Виктория Алонсо, Митчелл Белл, Эри Коста]
# Оператор                                                [Трент Опалок]
# Композитор                                           [Алан Сильвестри]
# Художник                         [Чарльз Вуд, Джулиан Эшби, Джим Барр]
# Монтаж                                    [Джеффри Форд, Мэттью Шмидт]
# Премьера в Росcии                               [3 мая 2018, «WDSSPR»]
# Премьера в мире                                       [23 апреля 2018]
# Цифровой релиз             [3 августа 2018, «Уолт Дисней Компани СНГ»]
# Релиз на DVD                                                      none
# Релиз на Blu-ray                                                  none
# Возраст                                                            16+
# Время                                                 149 мин. / 02:29
# Бюджет                                                  [$321 000 000]
# Сборы в США                                             [$678 815 482]
# Сборы в мире                [+ $1 369 544 272 = $2 048 359 754, сборы]
# Сборы в России                                           [$34 793 936]
# Рейтинг MPAA                PG-13детям до 13 лет просмотр не желателен
# Зрители                                                           none
# Ре-релиз (РФ)                                                     none
# Директор фильма                                                   none
# Маркетинг                                                         none
# Name: 73470, dtype: object
