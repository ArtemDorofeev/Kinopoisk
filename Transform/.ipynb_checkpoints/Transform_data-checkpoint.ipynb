# %%
# Подключаем библиотеки

import pandas as pd
import numpy as np
import json
import csv
import os

# %%
# Получаем список дирректорий с CSV файлами

dirs = os.listdir(path="D:\\Data\\Kinopoisk\\CSV\\characteristics")

# %%
# Объединяем все CSV файлы из нескольких дирректорий

lnk = 'D:\\Data\\Kinopoisk\\CSV\\characteristics\\{}'
dataset = pd.DataFrame()
for i in dirs:
    lst = lnk.format(i)
    fls = os.listdir(path=lst)
    for j in fls:
        d = pd.read_csv(lst+'\\'+j)
        dataset = pd.concat([dataset, d], ignore_index=True)

# %%
# Обзор итогового датасета

dataset
# Out:
#         Unnamed: 0                                name  \
# 0                0                      Игра престолов
# 1                1                         Рик и Морти
# 2                2                             Легенда
# 3                3                           Марсианин
# 4                4                         Головоломка
# ...            ...                                 ...
# 345495      347995                         Диссидентка
# 345496      347996               Москва. Полный ицукен
# 345497      347997          Лесенка знаний: мастерство
# 345498      347998  Долгое эхо Роберта Рождественского
# 345499      347999                           Eigengrau
#
#                                            links  year    type  \
# 0        https://www.kinopoisk.ru/series/464963/  2015  series
# 1        https://www.kinopoisk.ru/series/685246/  2015  series
# 2          https://www.kinopoisk.ru/film/839954/  2015    film
# 3          https://www.kinopoisk.ru/film/841700/  2015    film
# 4          https://www.kinopoisk.ru/film/645118/  2015    film
# ...                                          ...   ...     ...
# 345495    https://www.kinopoisk.ru/film/5020900/  2022    film
# 345496    https://www.kinopoisk.ru/film/5020961/  2022    film
# 345497  https://www.kinopoisk.ru/series/5021722/  2022  series
# 345498    https://www.kinopoisk.ru/film/5023658/  2022    film
# 345499    https://www.kinopoisk.ru/film/5030863/  2022    film
#
#                                                      char
# 0       [[{'name': 'Игра престолов (сериал 2011 – 2019...
# 1       [[{'name': 'Рик и Морти (сериал 2013 – ...)', ...
# 2       [[{'name': 'Легенда (2015)', 'description': 'Г...
# 3       [[{'name': 'Марсианин (2015)', 'description': ...
# 4       [[{'name': 'Головоломка (2015)', 'description'...
# ...                                                   ...
# 345495  [[{'name': 'Диссидентка (2022)', 'description'...
# 345496  [[{'name': 'Москва. Полный ицукен (ТВ, 2022)',...
# 345497  [[{'name': 'Лесенка знаний: мастерство (сериал...
# 345498  [[{'name': 'Долгое эхо Роберта Рождественского...
# 345499  [[{'name': 'Eigengrau (ТВ, 2022)', 'descriptio...
#
# [345500 rows x 6 columns]

# %%
# Создаем копию датасета

df = dataset.copy()
df.sample(10)
# Out:
#         Unnamed: 0                            name  \
# 53242        56742                     Günashim ol
# 188233      188233                             JED
# 75787        77287                    Дочки-мачехи
# 101879      101879     Refugee Baby: A Documentary
# 249863      249863  Detective MJ: Shadow of a Hero
# 91840        91340                    The Henchman
# 215325      215325                 The Granny Flat
# 208229      208229                  Nimki Vidhayak
# 260896      260896                     Video Vista
# 171040      171040                         I Dance
#
#                                            links  year    type  \
# 53242   https://www.kinopoisk.ru/series/1147065/  2016  series
# 188233    https://www.kinopoisk.ru/film/1133053/  2019    film
# 75787   https://www.kinopoisk.ru/series/1111700/  2017  series
# 101879     https://www.kinopoisk.ru/film/952587/  2017    film
# 249863    https://www.kinopoisk.ru/film/1283737/  2020    film
# 91840     https://www.kinopoisk.ru/film/1083643/  2017    film
# 215325    https://www.kinopoisk.ru/film/1348711/  2019    film
# 208229  https://www.kinopoisk.ru/series/1406453/  2019  series
# 260896    https://www.kinopoisk.ru/film/4754431/  2020    film
# 171040    https://www.kinopoisk.ru/film/1261253/  2018    film
#
#                                                      char
# 53242   [[{'name': 'Günashim ol (сериал 2016)', 'descr...
# 188233  [[{'name': 'JED (2019)', 'description': 'none'...
# 75787   [[{'name': 'Дочки-мачехи (мини–сериал 2017)', ...
# 101879  [[{'name': 'Refugee Baby: A Documentary (2017)...
# 249863  [[{'name': 'Detective MJ: Shadow of a Hero (20...
# 91840   [[{'name': 'The Henchman (2017)', 'description...
# 215325  [[{'name': 'The Granny Flat (2019)', 'descript...
# 208229  [[{'name': 'Nimki Vidhayak (сериал 2019 – 2020...
# 260896  [[{'name': 'Video Vista (ТВ, 2020)', 'descript...
# 171040  [[{'name': 'I Dance (2018)', 'description': 'n...

# %%
# Убираем строки с пустыми списками характеристик (выдавали ошибку 404)

df = df[df['char'] != '[]']

# %%
# Преобразуем стрковый формат характеристик в список

df['charlist'] = df['char'].apply(lambda x: eval(x))

# %%
# Сохраняем целевые поля в датасете

df = df[['name', 'links', 'year', 'type', 'charlist']]
df.sample(8)
# Out:
#                                                name  \
# 122605                                       Undone
# 212908                          A Son Never Forgets
# 130120                          Тайны высоких широт
# 9477    The Duggars Respond to Sexual Abuse Scandal
# 69725                                       Mirrors
# 294243                                  Happy Place
# 71062                                Psycho Therapy
# 190912                           Zaferanieh, July 5
#
#                                          links  year  type  \
# 122605  https://www.kinopoisk.ru/film/4807721/  2017  film
# 212908  https://www.kinopoisk.ru/film/1317747/  2019  film
# 130120  https://www.kinopoisk.ru/film/1142659/  2018  film
# 9477     https://www.kinopoisk.ru/film/930098/  2015  film
# 69725   https://www.kinopoisk.ru/film/1365238/  2016  film
# 294243  https://www.kinopoisk.ru/film/1446120/  2021  film
# 71062   https://www.kinopoisk.ru/film/1062415/  2016  film
# 190912  https://www.kinopoisk.ru/film/1359895/  2019  film
#
#                                                  charlist
# 122605  [[{'name': 'Undone (2017)', 'description': 'no...
# 212908  [[{'name': 'A Son Never Forgets (2019)', 'desc...
# 130120  [[{'name': 'Тайны высоких широт (ТВ, 2018)', '...
# 9477    [[{'name': 'The Duggars Respond to Sexual Abus...
# 69725   [[{'name': 'Mirrors (2016)', 'description': 'n...
# 294243  [[{'name': 'Happy Place (2021)', 'description'...
# 71062   [[{'name': 'Psycho Therapy (2016)', 'descripti...
# 190912  [[{'name': 'Zaferanieh, July 5 (2019)', 'descr...

# %%
#df.to_csv('D:\\Data\\Kino_draft\\csvchars_total.csv')

# %%
# Разбиваем словарь с названием, годом выпуска и описанием фильма по столбцам

df['full_name'] = df['charlist'].apply(lambda x: x[0][0]['name'])
df['rating'] = df['charlist'].apply(lambda x: x[0][0]['rating'])
df['quant_grad'] = df['charlist'].apply(lambda x: x[0][0]['grades'])
df['description'] = df['charlist'].apply(lambda x: x[0][0])

# %%
# Определяем функцию для составления списка всех уникальных заголовков характеристик

merg = []

def keys_unique(row):
    dcts = row[1]
    for i in dcts:
        k = list(i)
        if k not in merg:
            merg.append(k)

# %%
# Применяем функцию к серии со списком характеристик

df['charlist'].apply(keys_unique)
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 345495    None
# 345496    None
# 345497    None
# 345498    None
# 345499    None
# Name: charlist, Length: 344814, dtype: object

# %%
# Список заголовков всех характеристик фильма

merg
# Out:
# [['Год производства'],
#  ['Платформа'],
#  ['Страна'],
#  ['Жанр'],
#  ['Слоган'],
#  ['Режиссер'],
#  ['Сценарий'],
#  ['Продюсер'],
#  ['Оператор'],
#  ['Композитор'],
#  ['Художник'],
#  ['Монтаж'],
#  ['Премьера в Росcии'],
#  ['Премьера в мире'],
#  ['Цифровой релиз'],
#  ['Релиз на DVD'],
#  ['Релиз на Blu-ray'],
#  ['Возраст'],
#  ['Время'],
#  ['Бюджет'],
#  ['Сборы в США'],
#  ['Сборы в мире'],
#  ['Сборы в России'],
#  ['Рейтинг MPAA'],
#  ['Зрители'],
#  ['Ре-релиз (РФ)'],
#  ['Директор фильма'],
#  ['Маркетинг']]

# %%
# Определяем функцию распределения значений характеристик по отдельным столбцам

def podbor(row):
    global i
    x = row[1]
    for j in x:
        if i == list(j):
            n = j.get(i[0])
            break
        else:
            n = 'none'
    return n

# %%
# Выделяем каждую характеристику из общего списка в отдельный столбец

for i in merg:
    df[i[0]] = df['charlist'].apply(podbor)

# %%
df.sample(5)
# Out:
#                                             name  \
# 81058                            Убийство в лесу
# 254045                                      Gigi
# 92998                                     PickUp
# 129067                          Троил и Крессида
# 108788  Perverts Anonymous: Episode 1, Disguises
#
#                                          links  year  type  \
# 81058   https://www.kinopoisk.ru/film/1006196/  2017  film
# 254045  https://www.kinopoisk.ru/film/1376025/  2020  film
# 92998   https://www.kinopoisk.ru/film/1074330/  2017  film
# 129067  https://www.kinopoisk.ru/film/1200979/  2018  film
# 108788  https://www.kinopoisk.ru/film/1063790/  2017  film
#
#                                                  charlist  \
# 81058   [[{'name': 'Убийство в лесу (2017)', 'descript...
# 254045  [[{'name': 'Gigi (2020)', 'description': 'none...
# 92998   [[{'name': 'PickUp (2017)', 'description': 'no...
# 129067  [[{'name': 'Троил и Крессида (2018)', 'descrip...
# 108788  [[{'name': 'Perverts Anonymous: Episode 1, Dis...
#
#                                                 full_name rating quant_grad  \
# 81058                              Убийство в лесу (2017)      –
# 254045                                        Gigi (2020)      –
# 92998                                       PickUp (2017)      –
# 129067                            Троил и Крессида (2018)      –
# 108788  Perverts Anonymous: Episode 1, Disguises (ТВ, ...      –
#
#                                               description  \
# 81058   {'name': 'Убийство в лесу (2017)', 'descriptio...
# 254045  {'name': 'Gigi (2020)', 'description': 'none',...
# 92998   {'name': 'PickUp (2017)', 'description': 'none...
# 129067  {'name': 'Троил и Крессида (2018)', 'descripti...
# 108788  {'name': 'Perverts Anonymous: Episode 1, Disgu...
#
#                                          Год производства  ...  \
# 81058   [[2017, /lists/movies/year--2017/?b=films&b=top]]  ...
# 254045  [[2020, /lists/movies/year--2020/?b=films&b=top]]  ...
# 92998   [[2017, /lists/movies/year--2017/?b=films&b=top]]  ...
# 129067  [[2018, /lists/movies/year--2018/?b=films&b=top]]  ...
# 108788  [[2017, /lists/movies/year--2017/?b=films&b=top]]  ...
#
#                    Время Бюджет Сборы в США  \
# 81058                  —   none        none
# 254045                 —   none        none
# 92998    80 мин. / 01:20   none        none
# 129067  210 мин. / 03:30   none        none
# 108788           22 мин.   none        none
#
#                                              Сборы в мире Сборы в России  \
# 81058   [[$10 065, /film/1006196/box/], [сборы, /film/...           none
# 254045                                               none           none
# 92998                                                none           none
# 129067                                               none           none
# 108788                                               none           none
#
#        Рейтинг MPAA Зрители Ре-релиз (РФ) Директор фильма Маркетинг
# 81058          none    none          none            none      none
# 254045         none    none          none            none      none
# 92998          none    none          none            none      none
# 129067         none    none          none            none      none
# 108788         none    none          none            none      none
#
# [5 rows x 37 columns]

# %%
# Определяем функцию по выделению значения характеристики из списка

def sort(row):
    if type(row) == list:
        lst = []
        for i in row:
            val = i[0]
            if val != '...':
                lst.append(val)
        return lst
    else:
        return row

# %%
# Отделяем значения характеристик от второстепенных данных списка

for i in merg:
    df[i[0]] = df[i[0]].apply(sort)

# %%
# Определяем функции по выделению имен, ссылок актеров и оценок кинокритиков

def name_actor(row):
    n = []
    if row[2]:        
        dct = row[2]
        for i in dct:
            name = i['actor_name']
            n.append(name)
    else:
        n = n
    return n

def link_actor(row):
    n = []
    if row[2]:        
        dct = row[2]
        for i in dct:
            link = i['link']
            n.append(link)
    else:
        n = n
    return n

def rate_critic(row):    
    if row[3]:        
        rate = row[3][0]        
    else:
        rate = 'none'
    return rate

def grade_critic(row):    
    if row[3]:        
        grade = row[3][1]        
    else:
        grade = 'none'
    return grade

# %%
# Разбиваем актеров и рейтинги критиков по отдельным столбцам

df['Актеры'] = df['charlist'].apply(name_actor)
df['Актеры ссылки'] = df['charlist'].apply(link_actor)

df['Рейтинг критиков'] = df['charlist'].apply(rate_critic)
df['Оценок критиков'] = df['charlist'].apply(grade_critic)

# %%
df[['Оценок критиков', 'Баллы критиков']] = df['Оценок критиков'].str.split('оценок', 1, expand= True)

# %%
df[df['links'] == 'https://www.kinopoisk.ru/film/843649/']
# Out:
#                                  name                                  links  \
# 123470  Мстители: Война бесконечности  https://www.kinopoisk.ru/film/843649/
#
#         year  type                                           charlist  \
# 123470  2018  film  [[{'name': 'Мстители: Война бесконечности (201...
#
#                                    full_name rating      quant_grad  \
# 123470  Мстители: Война бесконечности (2018)    8.1  761 727 оценок
#
#                                               description Год производства  \
# 123470  {'name': 'Мстители: Война бесконечности (2018)...           [2018]
#
#         ...                                Рейтинг MPAA Зрители Ре-релиз (РФ)  \
# 123470  ...  PG-13детям до 13 лет просмотр не желателен    none          none
#
#        Директор фильма Маркетинг  \
# 123470            none      none
#
#                                                    Актеры  \
# 123470  [Роберт Дауни мл., Крис Хемсворт, Марк Руффало...
#
#                                             Актеры ссылки Рейтинг критиков  \
# 123470  [/name/10096/, /name/1300401/, /name/10467/, /...              85%
#
#        Оценок критиков Баллы критиков
# 123470            489             7.6
#
# [1 rows x 42 columns]

# %%
df.loc[123470]
# Out:
# name                                     Мстители: Война бесконечности
# links                            https://www.kinopoisk.ru/film/843649/
# year                                                              2018
# type                                                              film
# charlist             [[{'name': 'Мстители: Война бесконечности (201...
# full_name                         Мстители: Война бесконечности (2018)
# rating                                                             8.1
# quant_grad                                              761 727 оценок
# description          {'name': 'Мстители: Война бесконечности (2018)...
# Год производства                                                [2018]
# Платформа                                                         none
# Страна                                                           [США]
# Жанр                          [фантастика, боевик, приключения, слова]
# Слоган                          «An entire universe. Once and for all»
# Режиссер                                     [Энтони Руссо, Джо Руссо]
# Сценарий                   [Кристофер Маркус, Стивен МакФили, Стэн Ли]
# Продюсер                    [Виктория Алонсо, Митчелл Белл, Эри Коста]
# Оператор                                                [Трент Опалок]
# Композитор                                           [Алан Сильвестри]
# Художник                         [Чарльз Вуд, Джулиан Эшби, Джим Барр]
# Монтаж                                    [Джеффри Форд, Мэттью Шмидт]
# Премьера в Росcии                               [3 мая 2018, «WDSSPR»]
# Премьера в мире                                       [23 апреля 2018]
# Цифровой релиз             [3 августа 2018, «Уолт Дисней Компани СНГ»]
# Релиз на DVD                                                      none
# Релиз на Blu-ray                                                  none
# Возраст                                                            16+
# Время                                                 149 мин. / 02:29
# Бюджет                                                  [$321 000 000]
# Сборы в США                                             [$678 815 482]
# Сборы в мире                [+ $1 369 544 272 = $2 048 359 754, сборы]
# Сборы в России                                           [$34 793 936]
# Рейтинг MPAA                PG-13детям до 13 лет просмотр не желателен
# Зрители                                                           none
# Ре-релиз (РФ)                                                     none
# Директор фильма                                                   none
# Маркетинг                                                         none
# Актеры               [Роберт Дауни мл., Крис Хемсворт, Марк Руффало...
# Актеры ссылки        [/name/10096/, /name/1300401/, /name/10467/, /...
# Рейтинг критиков                                                   85%
# Оценок критиков                                                   489
# Баллы критиков                                                     7.6
# Name: 123470, dtype: object
