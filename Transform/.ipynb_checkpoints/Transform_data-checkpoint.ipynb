# %%
import pandas as pd
import numpy as np
import json
import csv
import os

# %%
dirs = os.listdir(path="D:\\Data\\Kinopoisk\\CSV\\characteristics")

# %%
lnk = 'D:\\Data\\Kinopoisk\\CSV\\characteristics\\{}'
dataset = pd.DataFrame()
for i in dirs:
    lst = lnk.format(i)
    fls = os.listdir(path=lst)
    for j in fls:
        d = pd.read_csv(lst+'\\'+j)
        dataset = pd.concat([dataset, d], ignore_index=True)

# %%
dataset
# Out:
#         Unnamed: 0                                name  \
# 0                0                      Игра престолов
# 1                1                         Рик и Морти
# 2                2                             Легенда
# 3                3                           Марсианин
# 4                4                         Головоломка
# ...            ...                                 ...
# 277495      347995                         Диссидентка
# 277496      347996               Москва. Полный ицукен
# 277497      347997          Лесенка знаний: мастерство
# 277498      347998  Долгое эхо Роберта Рождественского
# 277499      347999                           Eigengrau
#
#                                            links  year    type  \
# 0        https://www.kinopoisk.ru/series/464963/  2015  series
# 1        https://www.kinopoisk.ru/series/685246/  2015  series
# 2          https://www.kinopoisk.ru/film/839954/  2015    film
# ...

# %%
df = dataset.copy()
df.sample(10)
# Out:
#         Unnamed: 0                  name  \
# 253775      313775  The Space Between Us
# 202122      257122     Beyond This World
# 52978       107978             Okokok 70
# 174142      229142      A Touch Too Much
# 94654       149654             Quick Fix
# 218106      273106       Therapy Session
# 147212      202212           Bir Al-Abed
# 260392      330892            Italofobia
# 240219      300219               Waylaid
# 48624       103624      Le voleur du zoo
#
#                                          links  year  type  \
# 253775  https://www.kinopoisk.ru/film/4748367/  2021  film
# 202122  https://www.kinopoisk.ru/film/1401606/  2020  film
# 52978   https://www.kinopoisk.ru/film/1088165/  2017  film
# 174142  https://www.kinopoisk.ru/film/1222993/  2019  film
# 94654   https://www.kinopoisk.ru/film/1372406/  2018  film
# 218106  https://www.kinopoisk.ru/film/4480410/  2020  film
# 147212  https://www.kinopoisk.ru/film/1276915/  2019  film
# ...

# %%
df = df[df['char'] != '[]']

# %%
df['charlist'] = df['char'].apply(lambda x: eval(x))

# %%
df.sample(10)
# Out:
#         Unnamed: 0                               name  \
# 105615      160615                  The Morning After
# 183949      238949                Бегай, пока молодой
# 275144      345644                    Beat the Spread
# 232030      287030                             Ramyug
# 196319      251319             Carlota la mas barrial
# 222618      277618                       Rani ka raja
# 221056      276056  Een man die stiekem een gewei had
# 231591      286591           Легенда Дальнего Востока
# 28191        34191                      Say Something
# 100624      155624              Revenge of Crazy Face
#
#                                            links  year    type  \
# 105615    https://www.kinopoisk.ru/film/1182995/  2018    film
# 183949  https://www.kinopoisk.ru/series/1234941/  2020  series
# 275144    https://www.kinopoisk.ru/film/5121014/  2022    film
# 232030  https://www.kinopoisk.ru/series/1227089/  2021  series
# ...

# %%
#df.to_csv('D:\\Data\\Kinopoisk\\characteristics\\char100_250.csv')

# %%
df['full_name'] = df['charlist'].apply(lambda x: x[0][0]['name'])
df['rating'] = df['charlist'].apply(lambda x: x[0][0]['rating'])
df['quant_grad'] = df['charlist'].apply(lambda x: x[0][0]['grades'])
df['description'] = df['charlist'].apply(lambda x: x[0][0])

# %%
#df['charlist'].values

# %%
merg = []

def keys_unique(row):
    dcts = row[1]
    for i in dcts:
        k = list(i)
        if k not in merg:
            merg.append(k)

# %%
df['charlist'].apply(keys_unique)
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 277495    None
# 277496    None
# 277497    None
# 277498    None
# 277499    None
# Name: charlist, Length: 276852, dtype: object

# %%
merg
# Out:
# [['Год производства'],
#  ['Платформа'],
#  ['Страна'],
#  ['Жанр'],
#  ['Слоган'],
#  ['Режиссер'],
#  ['Сценарий'],
#  ['Продюсер'],
#  ['Оператор'],
#  ['Композитор'],
#  ['Художник'],
#  ['Монтаж'],
#  ['Премьера в Росcии'],
#  ['Премьера в мире'],
#  ['Цифровой релиз'],
#  ['Релиз на DVD'],
#  ['Релиз на Blu-ray'],
#  ['Возраст'],
#  ['Время'],
#  ['Бюджет'],
#  ['Сборы в США'],
#  ['Сборы в мире'],
#  ['Сборы в России'],
#  ['Рейтинг MPAA'],
#  ['Зрители'],
#  ['Ре-релиз (РФ)'],
#  ['Директор фильма'],
#  ['Маркетинг']]

# %%
def podbor(row):
    global i
    x = row[1]
    for j in x:
        if i == list(j):
            n = j.get(i[0])
            break
        else:
            n = 'none'
    return n

# %%
for i in merg:
    df[i[0]] = df['charlist'].apply(podbor)

# %%
def sort(row):
    if type(row) == list:
        lst = []
        for i in row:
            val = i[0]
            if val != '...':
                lst.append(val)
        return lst
    else:
        return row

# %%
for i in merg:
    df[i[0]] = df[i[0]].apply(sort)

# %%
df.loc[68470]
# Out:
# Unnamed: 0                                                      123470
# name                                     Мстители: Война бесконечности
# links                            https://www.kinopoisk.ru/film/843649/
# year                                                              2018
# type                                                              film
# char                 [[{'name': 'Мстители: Война бесконечности (201...
# charlist             [[{'name': 'Мстители: Война бесконечности (201...
# full_name                         Мстители: Война бесконечности (2018)
# rating                                                             8.1
# quant_grad                                              761 727 оценок
# description          {'name': 'Мстители: Война бесконечности (2018)...
# Год производства                                                   [2]
# Платформа                                                         none
# ...

# %%
df[df['links'] == 'https://www.kinopoisk.ru/film/843649/']
# Out:
#        Unnamed: 0                           name  \
# 68470      123470  Мстители: Война бесконечности
#
#                                        links  year  type  \
# 68470  https://www.kinopoisk.ru/film/843649/  2018  film
#
#                                                     char  \
# 68470  [[{'name': 'Мстители: Война бесконечности (201...
#
#                                                 charlist  \
# 68470  [[{'name': 'Мстители: Война бесконечности (201...
#
#                                   full_name rating      quant_grad  ...  \
# 68470  Мстители: Война бесконечности (2018)    8.1  761 727 оценок  ...
#
#                   Время          Бюджет     Сборы в США  \
# 68470  149 мин. / 02:29  [$321 000 000]  [$678 815 482]
#
#                                      Сборы в мире Сборы в России  \
# 68470  [+ $1 369 544 272 = $2 048 359 754, сборы]  [$34 793 936]
#
#                                      Рейтинг MPAA Зрители Ре-релиз (РФ)  \
# ...
