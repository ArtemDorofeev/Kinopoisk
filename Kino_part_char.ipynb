# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import lxml
import json
import time
import csv
import random

# %%
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

# %%
service = Service(executable_path=ChromeDriverManager().install())
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.79M/6.79M [00:04<00:00, 1.58MB/s]

# %%
# Загружаем датафрейм ссылок

lnk_csv = 'https://raw.githubusercontent.com/ArtemDorofeev/Kinopoisk/main/csv/df_2015_2022.csv'
data = pd.read_csv(lnk_csv)
df_full = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       1 # Загружаем датафрейм ссылок
#       3 lnk_csv = 'https://raw.githubusercontent.com/ArtemDorofeev/Kinopoisk/main/csv/df_{}.csv'
# ----> 4 data = pd.read_csv(lnk_csv.format(i))
#       5 df_full = pd.DataFrame(data)
#
# NameError: name 'i' is not defined

# %%
#df_full = df_full[['name', 'links', 'year']]
df_full
# Out:
#                                 name                                    links  \
# 0                     Игра престолов  https://www.kinopoisk.ru/series/464963/
# 1                        Рик и Морти  https://www.kinopoisk.ru/series/685246/
# 2                            Легенда    https://www.kinopoisk.ru/film/839954/
# 3                          Марсианин    https://www.kinopoisk.ru/film/841700/
# 4                        Головоломка    https://www.kinopoisk.ru/film/645118/
# ...                              ...                                      ...
# 377994            Музыка летней ночи   https://www.kinopoisk.ru/film/5073920/
# 377995                      Пингвины   https://www.kinopoisk.ru/film/5074010/
# 377996                      Прогресс   https://www.kinopoisk.ru/film/5074011/
# 377997                        Прятки   https://www.kinopoisk.ru/film/5074012/
# 377998  Фантасмагория в стиле модерн   https://www.kinopoisk.ru/film/5074019/
#
#         year
# 0       2015
# 1       2015
# 2       2015
# 3       2015
# 4       2015
# ...      ...
# 377994  2022
# 377995  2022
# 377996  2022
# 377997  2022
# 377998  2022
#
# [377999 rows x 3 columns]

# %%
duplicate = df_full['links'].duplicated()
duplicate.value_counts()

df = df_full.drop(index=df_full[duplicate].index, axis=0)

# %%
df
# Out:
#                                 name                                    links  \
# 0                     Игра престолов  https://www.kinopoisk.ru/series/464963/
# 1                        Рик и Морти  https://www.kinopoisk.ru/series/685246/
# 2                            Легенда    https://www.kinopoisk.ru/film/839954/
# 3                          Марсианин    https://www.kinopoisk.ru/film/841700/
# 4                        Головоломка    https://www.kinopoisk.ru/film/645118/
# ...                              ...                                      ...
# 377994            Музыка летней ночи   https://www.kinopoisk.ru/film/5073920/
# 377995                      Пингвины   https://www.kinopoisk.ru/film/5074010/
# 377996                      Прогресс   https://www.kinopoisk.ru/film/5074011/
# 377997                        Прятки   https://www.kinopoisk.ru/film/5074012/
# 377998  Фантасмагория в стиле модерн   https://www.kinopoisk.ru/film/5074019/
#
#         year
# 0       2015
# 1       2015
# 2       2015
# 3       2015
# 4       2015
# ...      ...
# 377994  2022
# 377995  2022
# 377996  2022
# 377997  2022
# 377998  2022
#
# [348024 rows x 3 columns]

# %%
def split_serials(row):
    if 'film' in row:
        x = 'film'
    else:
        x = 'series'
    return x

# %%
df['type'] = df['links'].apply(split_serials)
df
# Out:
#                                 name                                    links  \
# 0                     Игра престолов  https://www.kinopoisk.ru/series/464963/
# 1                        Рик и Морти  https://www.kinopoisk.ru/series/685246/
# 2                            Легенда    https://www.kinopoisk.ru/film/839954/
# 3                          Марсианин    https://www.kinopoisk.ru/film/841700/
# 4                        Головоломка    https://www.kinopoisk.ru/film/645118/
# ...                              ...                                      ...
# 377994            Музыка летней ночи   https://www.kinopoisk.ru/film/5073920/
# 377995                      Пингвины   https://www.kinopoisk.ru/film/5074010/
# 377996                      Прогресс   https://www.kinopoisk.ru/film/5074011/
# 377997                        Прятки   https://www.kinopoisk.ru/film/5074012/
# 377998  Фантасмагория в стиле модерн   https://www.kinopoisk.ru/film/5074019/
#
#         year    type
# 0       2015  series
# 1       2015  series
# 2       2015    film
# 3       2015    film
# 4       2015    film
# ...      ...     ...
# 377994  2022    film
# 377995  2022    film
# 377996  2022    film
# 377997  2022    film
# 377998  2022    film
#
# [348024 rows x 4 columns]

# %%
df_2015 = df[df['year'] == 2015]
df_2016 = df[df['year'] == 2016]
df_2017 = df[df['year'] == 2017]
df_2018 = df[df['year'] == 2018]
df_2019 = df[df['year'] == 2019]
df_2020 = df[df['year'] == 2020]
df_2021 = df[df['year'] == 2021]
df_2022 = df[df['year'] == 2022]

# %%
df_2015
# Out:
#                                      name  \
# 0                          Игра престолов
# 1                             Рик и Морти
# 2                                 Легенда
# 3                               Марсианин
# 4                             Головоломка
# ...                                   ...
# 36945                De Kleine Zeemeermin
# 36946   Она решила — хватит значит хватит
# 36947                      Воины Ватерлоо
# 36948  Корейский альбом, без комментариев
# 36949                  Американская мечта
#
#                                           links  year    type
# 0       https://www.kinopoisk.ru/series/464963/  2015  series
# 1       https://www.kinopoisk.ru/series/685246/  2015  series
# 2         https://www.kinopoisk.ru/film/839954/  2015    film
# 3         https://www.kinopoisk.ru/film/841700/  2015    film
# 4         https://www.kinopoisk.ru/film/645118/  2015    film
# ...                                         ...   ...     ...
# 36945  https://www.kinopoisk.ru/series/1047265/  2015  series
# 36946    https://www.kinopoisk.ru/film/1162789/  2015    film
# 36947    https://www.kinopoisk.ru/film/1199824/  2015    film
# 36948    https://www.kinopoisk.ru/film/1354874/  2015    film
# 36949    https://www.kinopoisk.ru/film/4474709/  2015    film
#
# [36950 rows x 4 columns]

# %%
# Формируем суп-объект

def get_soup(url):    
    driver.get(url)    
    html = driver.page_source
    soup = BeautifulSoup(html, "lxml")
    #info_section = soup.select('div.styles_root__2kxYy')
    return soup

# %%
def get_top(row):
    list_top = []
    try:
        name = row.select_one('h1[class*="styles_title"]').get_text()
    except:
        name = []
    
    try:
        description = row.select_one('div[class*="styles_topText"]').get_text()
    except:
        description = []
        
    try:
        rating = row.select_one('span[class*="film-rating-value"]').get_text()
    except:
        rating = []
        
    try:
        grades = row.select_one('div[class*="styles_countBlock"]').get_text()
    except:
        grades = []
    
    dic = {'name': name, 'description': description, 'rating': rating, 'grades': grades}
    list_top.append(dic)
    return list_top

def get_about(row):    
    about_block = row.select_one('div[data-test-id*="encyclopedic-table"]')
    about_row = about_block.select('div[class*="styles_row"]')
    list_about = []
    for i in about_block:
        try:            
            title = i.select_one('div[class*="styles_title"]').get_text()
            values = i.select('div[class*="styles_value"]')    
            dic = {title: values}
        except:
            dic = {}
        list_about.append(dic)        
    return list_about


def get_actor(row):
    list_actor = []
    try:        
        actor_block = row.select('div[class*="styles_actors"] ul li')        
        for i in actor_block:
            link = i.select_one('a').get('href')
            actor_name = i.get_text()
            dic = {'actor_name': actor_name, 'link': link}
            list_actor.append(dic)
    except:
        list_actor = list_actor
    return list_actor

def get_low(row):    
    try:
        critic_section = row.select_one('div[class*="styles_criticRatingSection"]')    
        try:
            critic_positive = critic_section.select_one('span[class*="film-rating-value"]').get_text()
        except:
            critic_positive = []
        try:   
            critic_value = critic_section.select_one('div[class*="styles_countBlock"]').get_text()
        except:
            critic_value = []
        try:
            critic_star = critic_section.select_one('div[class*="styles_starValue"]').get_text()
        except:
            critic_star = []
        lst = [critic_positive, critic_value, critic_star]
    except:
        lst = []
    return lst

# %%
def full_parse(row):    
    #time.sleep(tm)
    soup = get_soup(row)
    name_rate = get_top(soup)
    about_film = get_about(soup)
    actors = get_actor(soup)
    critic_rate = get_low(soup)
    dic = {'name_rate': name_rate, 'about_film': about_film, 'actors': actors, 'critic_rate': critic_rate}
    return dic

# %%
driver = webdriver.Chrome(service=service) # Открывает новую отдельную вкладку браузера хром от selenium

# %%
# ЗАПУСК ПАРСЕРА!!!

#df_2015['char'] = df_2015['links'].apply(full_parse)

# %%
lnks = list(df_2015['links'])

# %%
full_list = []
for i in lnks:
    try:
        n = full_parse(i)
    except:
        n = {}
    full_list.append(n)

# %%
full_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 full_list
#
# NameError: name 'full_list' is not defined

# %%
df_2015
# Out:
#                                      name  \
# 0                          Игра престолов
# 1                             Рик и Морти
# 2                                 Легенда
# 3                               Марсианин
# 4                             Головоломка
# ...                                   ...
# 36945                De Kleine Zeemeermin
# 36946   Она решила — хватит значит хватит
# 36947                      Воины Ватерлоо
# 36948  Корейский альбом, без комментариев
# 36949                  Американская мечта
#
#                                           links  year    type
# 0       https://www.kinopoisk.ru/series/464963/  2015  series
# 1       https://www.kinopoisk.ru/series/685246/  2015  series
# 2         https://www.kinopoisk.ru/film/839954/  2015    film
# 3         https://www.kinopoisk.ru/film/841700/  2015    film
# 4         https://www.kinopoisk.ru/film/645118/  2015    film
# ...                                         ...   ...     ...
# 36945  https://www.kinopoisk.ru/series/1047265/  2015  series
# 36946    https://www.kinopoisk.ru/film/1162789/  2015    film
# 36947    https://www.kinopoisk.ru/film/1199824/  2015    film
# 36948    https://www.kinopoisk.ru/film/1354874/  2015    film
# 36949    https://www.kinopoisk.ru/film/4474709/  2015    film
#
# [36950 rows x 4 columns]

# %%
#df_2015['char'][46179]

# %%
#df.to_csv('D:\\Data\\Kinopoisk\\csv\\df_2015-2022.csv')

# %%
driver.quit()
