# %%
import pandas as pd
import numpy as np
import json
import csv
import os

# %%
dirs = os.listdir(path="D:\\Data\\Kinopoisk\\CSV\\characteristics")

# %%
lnk = 'D:\\Data\\Kinopoisk\\CSV\\characteristics\\{}'
df = pd.DataFrame()
for i in dirs:
    lst = lnk.format(i)
    fls = os.listdir(path=lst)
    for j in fls:
        d = pd.read_csv(lst+'\\'+j)
        df = pd.concat([df, d], ignore_index = True)

# %%
df
# Out:
#          {  Unnamed: 0                                name  \
# 0      NaN         NaN                                 NaN
# 1      NaN         NaN                                 NaN
# 2      NaN         NaN                                 NaN
# 3      NaN         NaN                                 NaN
# 4      NaN         NaN                                 NaN
# ...     ..         ...                                 ...
# 277500 NaN    347995.0                         Диссидентка
# 277501 NaN    347996.0               Москва. Полный ицукен
# 277502 NaN    347997.0          Лесенка знаний: мастерство
# 277503 NaN    347998.0  Долгое эхо Роберта Рождественского
# 277504 NaN    347999.0                           Eigengrau
#
#                                            links    year    type  \
# 0                                            NaN     NaN     NaN
# 1                                            NaN     NaN     NaN
# 2                                            NaN     NaN     NaN
# 3                                            NaN     NaN     NaN
# 4                                            NaN     NaN     NaN
# ...                                          ...     ...     ...
# 277500    https://www.kinopoisk.ru/film/5020900/  2022.0    film
# 277501    https://www.kinopoisk.ru/film/5020961/  2022.0    film
# 277502  https://www.kinopoisk.ru/series/5021722/  2022.0  series
# 277503    https://www.kinopoisk.ru/film/5023658/  2022.0    film
# 277504    https://www.kinopoisk.ru/film/5030863/  2022.0    film
#
#                                                      char
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 277500  [[{'name': 'Диссидентка (2022)', 'description'...
# 277501  [[{'name': 'Москва. Полный ицукен (ТВ, 2022)',...
# 277502  [[{'name': 'Лесенка знаний: мастерство (сериал...
# 277503  [[{'name': 'Долгое эхо Роберта Рождественского...
# 277504  [[{'name': 'Eigengrau (ТВ, 2022)', 'descriptio...
#
# [277505 rows x 7 columns]
